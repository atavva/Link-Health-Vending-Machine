# %% [markdown]
# <h1> Link Health Vending Machine Policy Research </h1>

# %%
import pandas as pd
import numpy as np
import requests
import csv
import warnings
warnings.simplefilter('ignore') #Turn off warnings

# %% [markdown]
# <h2> Starting Work on Assistance Listings Database </h2>

# %%
asstList = pd.read_csv("CSVs/AssistanceListings_DataGov_PUBLIC_WEEKLY_20231021.csv", encoding='unicode_escape')

# %%
asstList.head()
# Out:
#                                        Program Title  Program Number  \
# 0   Agricultural Research Basic and Applied Research          10.001
# 1  Plant and Animal Disease, Pest Control, and An...          10.025
# 2                                  Wildlife Services          10.028
# 3                                  Indemnity Program          10.030
# 4       Commodity Loans and Loan Deficiency Payments          10.051
#
#                                   Popular Name (020)  \
# 0                              (Extramural Research)
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Marketing Assistance Loans (MAL's) and Loan De...
#
#                                 Federal Agency (030)  \
# 0  AGRICULTURAL RESEARCH SERVICE, AGRICULTURE, DE...
# 1  ANIMAL AND PLANT HEALTH INSPECTION SERVICE, AG...
# 2  ANIMAL AND PLANT HEALTH INSPECTION SERVICE, AG...
# 3  ANIMAL AND PLANT HEALTH INSPECTION SERVICE, AG...
# 4    FARM SERVICE AGENCY, AGRICULTURE, DEPARTMENT OF
#
#                                  Authorization (040)  \
# 0  {"list":[{"act":{"description":"Food Security ...
# 1  {"list":[{"act":{"description":"Plant Protecti...
# 2  {"list":[{"act":{"description":"Animal Damage ...
# 3  {"list":[{"act":{"description":"Plant Protecti...
# 4  {"list":[{"act":{"description":"Agricultural A...
#
#                                     Objectives (050)  \
# 0  To make agricultural research discoveries, eva...
# 1  To protect U.S. agriculture from economically ...
# 2  To reduce damage caused by mammals and birds a...
# 3  Animal and Plant Health Inspection Service adm...
# 4  To improve and stabilize farm income, to assis...
#
#                            Types of Assistance (060)  \
# 0                                     PROJECT GRANTS
# 1                                     PROJECT GRANTS
# 2                                     PROJECT GRANTS
# 3              DIRECT PAYMENTS WITH UNRESTRICTED USE
# 4  DIRECT PAYMENTS WITH UNRESTRICTED USE;DIRECT L...
#
#   Uses and Use Restrictions (070)  \
# 0                  Not Applicable
# 1                  Not Applicable
# 2                  Not Applicable
# 3                  Not Applicable
# 4                  Not Applicable
#
#                          Applicant Eligibility (081)  \
# 0  Usually nonprofit institutions of higher educa...
# 1  Foreign, State, local, and U.S. Territorial go...
# 2  State and local governments, federally recogni...
# 3                                                NaN
# 4  Owner, landlord, tenant, or sharecropper on an...
#
#                        Beneficiary Eligibility (082)  ...  \
# 0  Usually nonprofit institutions of higher educa...  ...
# 1  Farmers, ranchers, agriculture producers, Stat...  ...
# 2  States, local jurisdictions, U.S. Territorial ...  ...
# 3                                                NaN  ...
# 4  Owner, landlord, tenant, or sharecropper on a ...  ...
#
#                       Regional or Local Office (151)  \
# 0  {"flag":"appendix","description":"See the Agri...
# 1  {"flag":"appendix","description":"Consult Appe...
# 2  {"flag":"appendix","description":"See Appendix...
# 3                                {"flag":"appendix"}
# 4  {"flag":"appendix","description":"Consult the ...
#
#                            Headquarters Office (152)  \
# 0  Deborah Watson5601 Sunnyside Avenue, MS 5110, ...
# 1  Eileen M. Berke,4700 River Road, Unit 55, Rive...
# 2  Eileen M. Berke,4700 River Road, Unit 55, Suit...
# 3  Donna Cichy100 North 6th Street, Suite 510C\r\...
# 4  Shayla Watson1400 Independence Avenue, SW, Sto...
#
#                                Website Address (153)  \
# 0                            http://www.ars.usda.gov
# 1                         http://www.aphis.usda.gov/
# 2                          http://www.aphis.usda.gov
# 3                                     Not Applicable
# 4  http://www.fsa.usda.gov/programs-and-services/...
#
#                               Related Programs (160)  \
# 0  10.200 Grants for Agricultural Research, Speci...
# 1  10.219 Biotechnology Risk Assessment Research;...
# 2  15.611 Wildlife Restoration and Basic Hunter E...
# 3                                    Not Applicable.
# 4           10.155 Marketing Agreements and Orders;
#
#   Examples of Funded Projects (170)  \
# 0                   Not Applicable.
# 1                   Not Applicable.
# 2                   Not Applicable.
# 3                   Not Applicable.
# 4                   Not Applicable.
#
#               Criteria for Selecting Proposals (180) Published Date  \
# 0                                       Peer review.    Jan 01,1965
# 1                                    Not Applicable.    Jan 01,1972
# 2  Relevance to agency program mission and qualif...    Jan 01,1986
# 3                                    Not Applicable.    Mar 16,2012
# 4                                    Not Applicable.    Jan 01,1965
#
#   Parent Shortname                                                URL Recovery
# 0             USDA  https://sam.gov/fal/8138603977434d65a63073a7e5...       No
# 1             USDA  https://sam.gov/fal/47eecdfbe59743e998cf64dafa...       No
# 2             USDA  https://sam.gov/fal/5777f406178e4a95bc9d933a99...       No
# 3             USDA  https://sam.gov/fal/c94b7dc247f64502b368b72013...       No
# 4             USDA  https://sam.gov/fal/f20d78c22ec34c2d9df3f80ae0...       No
#
# [5 rows x 38 columns]

# %%
asstList = asstList[["Program Number", 
                     "Program Title", 
                     "Popular Name (020)",
                     "Objectives (050)",
                     "Applicant Eligibility (081)", 
                     "Beneficiary Eligibility (082)", 
                     "Published Date", 
                     "URL"]]

# %%
asstList.rename(columns = {"Applicant Eligibility (081)" : "Prerequisites",
                           "Beneficiary Eligibility (082)" : "Beneficiary", 
                           "Popular Name (020)" : "Popular Name", 
                           "Objectives (050)" : "Objectives"}, inplace = True)

# %%
asstList['Popular Name'] = asstList['Popular Name'].fillna('')

# %%
def programNameMerge(row):
    if row['Popular Name'] != '' and row['Popular Name'] != row["Program Title"]:
        return f"{row['Program Title']} or {row['Popular Name']}"
    else:
        return row['Program Title']

asstList["Program Title"] = asstList.apply(programNameMerge, axis=1)
asstList = asstList.drop("Popular Name", axis = 1)

# %% [markdown]
# <h2> Find Relevant Programs in Assistance Listing DB </h2>

# %% [markdown]
# <p> Organized the columns that we need to find prerequisites, now need to find a way to extract all relevant programs (i.e. ones for individuals rather than orgs.) </p>

# %%
# Want to keep all programs that have prereqs listed.
asstList = asstList[asstList["Prerequisites"].notnull()]
"Number of Programs with Prerequisites: " + str(len(asstList))
# Out:
# 'Number of Programs with Prerequisites: 2371'

# %%
# ACP Eligibility Requirements...
asstList[asstList["Program Title"] == "Affordable Connectivity Program"]["Prerequisites"].iloc[0]
# do all programs use ';' to split each prerequistes?
# Out:
# 'Provider Eligibility: In the Infrastructure Act, a \x93participating provider\x94 for the Affordable Connectivity Program shall be a broadband service provider that is either designated as an eligible telecommunications carrier (ETC) or seeks approval from the Commission for participation in the Affordable Connectivity Program. ETCs and non-ETCs must establish they provide broadband service to participate in the program. Household Eligibility: Support is available only for one line per household; applicants are eligible if at least one member of the household: Income is at or below 200% of the federal poverty guidelines; Meets the qualifications for participation in the Lifeline program, that is, if they participate in one of the following federal assistance programs: Medicaid, Supplemental Nutrition Assistance Program, Supplemental Security Income, Federal Public Housing Assistance, or Veterans Pension and Survivors Benefit; or one of the following Tribal-specific federal assistance programs: Bureau of Indian Affairs general assistance, Tribally-administered Temporary Assistance for Needy Families, Head Start (only those households meeting its income qualifying standard), or the Food Distribution Program on Indian Reservations; Receives benefits in the current school year under the free and reduced-price school lunch program or the school breakfast program, including through the USDA Community Eligibility Provision, or did so in the school year immediately preceding the application for the Affordable Connectivity Program; participates in the Special Supplemental Nutritional Program for Woman, Infants, and Children (WIC); Has received a Federal Pell Grant under section 401 of the Higher Education Act of 1965 in the current award year; or Meets the eligibility criteria for a participating provider\x92s existing low-income program, subject to approval by the Commission.'

# %%
wordsToAvoid = "nonprofit|institutions|organizations|cooperatives|pvo|ngo"
wordsWeWant = "individuals|applicants|household|person|families"
indPrograms = asstList[asstList["Beneficiary"].str.lower().str.contains(wordsWeWant) == True 
                       & asstList["Beneficiary"].str.lower().str.contains(wordsToAvoid) == False]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/rp/gtg5wbf11f18_fr068h4cjgw0000gn/T/ipykernel_44284/4025538.py in <module>
#       1 wordsToAvoid = "nonprofit|institutions|organizations|cooperatives|pvo|ngo"
#       2 wordsWeWant = "individuals|applicants|household|person|families"
# ----> 3 indPrograms = asstList[asstList["Beneficiary"].str.lower().str.contains(wordsWeWant) == True
#       4                        & asstList["Beneficiary"].str.lower().str.contains(wordsToAvoid) == False]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Formatting the dates in indPrograms.
monthDict = {"Jan" : "01", "Feb" : "02", "Mar" : "03", "Apr" : "04", "May" : "05", "Jun" : "06", "Jul" : "07", 
             "Aug" : "08", "Sep" : "09", "Oct" : "10", "Nov" : "11", "Dec" : "12"}

def formatDate(row):
    date = f"{row['Published Date']}"
    month = monthDict[date[:3]]
    day = date[4:6]
    year = date[7:11]
    return year + "-" + month + "-" + day

indPrograms["Published Date"] = indPrograms.apply(formatDate, axis = 1)
indPrograms.sort_values("Published Date")
# Out:
#       Program Number                                      Program Title  \
# 206           10.555      National School Lunch Program or School Lunch
# 567           14.128  Mortgage Insurance Hospitals or (Section 242 -...
# 569           14.133  Mortgage Insurance Purchase of Units in Condom...
# 145           10.405  Farm Labor Housing Loans and Grants or (Labor ...
# 146           10.406  Farm Operating Loans and Loan Guarantees or Fa...
# ...              ...                                                ...
# 1841          90.705  Southeast Crescent Regional Commission  - Econ...
# 143           10.384  Indigenous Animals Harvesting and Meat Process...
# 1659          66.965  Alaska Native Claims Settlement Act Contaminat...
# 1515          64.058  Veteran and Spouse Transitional Assistance Gra...
# 958           15.966  Historic Preservation Fund Grants-in-Aid for C...
#
#                                              Objectives  \
# 206   To assist States, through cash grants and food...
# 567   To facilitate the affordable financing of hosp...
# 569   To enable individuals and families to purchase...
# 145   To provide decent, safe, and sanitary low-rent...
# 146   The Farm Service Agency (FSA) offers direct an...
# ...                                                 ...
# 1841  The mission of the Commission is to help build...
# 143   This program will provide funds to Tribal gove...
# 1659  EPA is establishing and implementing a program...
# 1515  The Secretary of Veterans Affairs will make gr...
# 958   The objectives of the competitive grant progra...
#
#                                           Prerequisites  \
# 206   States, including the District of Columbia and...
# 567   Qualified applicants can be either profit or n...
# 569          All legal residents are eligible to apply.
# 145   Loans are available to farmers, family farm pa...
# 146   General Eligibility for Direct Loans\n\nThe fo...
# ...                                                 ...
# 1841  1.)\tState governments of Alabama, Florida, Ge...
# 143                                      Not Applicable
# 1659  Alaska Native Regional Corporations, Alaskan N...
# 1515  The following organizations and entities are e...
# 958   Eligible applicants are defined as applicants ...
#
#                                             Beneficiary Published Date  \
# 206   All children enrolled in schools where this pr...     1965-01-01
# 567   Persons needing the services of these hospital...     1965-01-01
# 569                               Individuals/families.     1965-01-01
# 145   A domestic farm laborer is any person who rece...     1965-01-01
# 146   Individual/Entity, Socially Disadvantaged Appl...     1965-01-01
# ...                                                 ...            ...
# 1841  Funds awarded under this listing must benefit ...     2023-03-03
# 143   Tribal governments as defined by the Federally...     2023-03-29
# 1659  Alaska Native Regional Corporations, Alaskan N...     2023-04-04
# 1515  Veteran/Service person/Reservist (including de...     2023-04-20
# 958   State, local, tribal, and territorial governme...     2023-07-25
#
#                                                     URL
# 206   https://sam.gov/fal/bf821e9376ce450e91ec88e172...
# 567   https://sam.gov/fal/8b065c2bc23f43029200c24cb4...
# 569   https://sam.gov/fal/329d2eca2ba04785a8eef2b26c...
# 145   https://sam.gov/fal/f6a2b763b3a44bff865e50e90a...
# 146   https://sam.gov/fal/75a2b880bdef42229df6b78d96...
# ...                                                 ...
# 1841  https://sam.gov/fal/5c16d3e634984e67b4b83993e4...
# 143   https://sam.gov/fal/7dc6d10cc7594f3cbd218e3156...
# 1659  https://sam.gov/fal/040fea5cb4584ab098f2fc7bad...
# 1515  https://sam.gov/fal/2e3c4cc68026412bb1ee8748c9...
# 958   https://sam.gov/fal/1ff74cb8daf64afe8c4320a13c...
#
# [499 rows x 7 columns]

# %%
# Sorting programs in ascending order by date. 
indPrograms = indPrograms.sort_values("Published Date", ascending = True)
# If no date set to oldest date...
# indPrograms = indPrograms[indPrograms["Prerequisites"] != "Not Applicable"]

# %% [markdown]
# <h2> Extracting individual Prerequistes from Prerequiste Text Block </h2>

# %%
prereqsSplit = indPrograms["Prerequisites"]

# %%
prereqsSplit[prereqsSplit.str.contains("requirements")].iloc[5]
# Out:
# 'FORMULA grants: States, Territories and Tribes as defined in the 54 USC 301 et seq (commonly known as the National Historic Preservation Act), operate programs administered by a State Historic Preservation Officer or Tribal Historic Preservation Officer appointed by the Governor, Tribal government or according to State or Tribal law, and which are otherwise in compliance with the requirements of the Act. \r\n\r\n\r\nPROJECT grants: Eligible tribal applicants include Federally recognized Indian Tribes, Alaska Native Corporations, and Native Hawaiian organizations.\r\n\r\nOther project grants follow eligibility as defined  by Congress and stated in statue or committee language.'

# %%
#removeTest = ['\n', '\t', 'I.', 'II.', 'III.', 'IV.', "V.", "VI.", 'VII.', 'VIII.', 'IX.', 'X.']

remove = ['\n', '\t']
newSplit = prereqsSplit
for char in remove:
    newSplit = newSplit.str.replace(char, '')
newSplit = newSplit.drop(2228).str.split(';', expand = True)

# droppign 2228 bc has like 50 splits, all useless..
# newSplit = prereqsSplit.drop(2228).str.replace('\n', '').str.replace('\t', '').str.split(';', expand = True)
newSplit
# Out:
#                                                      0   \
# 206   States, including the District of Columbia and...
# 567   Qualified applicants can be either profit or n...
# 569          All legal residents are eligible to apply.
# 145   Loans are available to farmers, family farm pa...
# 146   General Eligibility for Direct LoansThe follow...
# ...                                                 ...
# 2136  State (includes District of Columbia, public i...
# 1841  1.)State governments of Alabama, Florida, Geor...
# 1659  Alaska Native Regional Corporations, Alaskan N...
# 1515  The following organizations and entities are e...
# 958   Eligible applicants are defined as applicants ...
#
#                                                      1   \
# 206                                                None
# 567                                                None
# 569                                                None
# 145                                                None
# 146               II.Have a satisfactory credit history
# ...                                                 ...
# 2136                                               None
# 1841   § 200.1 Federally recognized Indian Tribe -  ...
# 1659                                               None
# 1515                                               None
# 958                                                None
#
#                                                      2   \
# 206                                                None
# 567                                                None
# 569                                                None
# 145                                                None
# 146   III.Be a citizen of the United States, includi...
# ...                                                 ...
# 2136                                               None
# 1841                                               None
# 1659                                               None
# 1515                                               None
# 958                                                None
#
#                                                      3   \
# 206                                                None
# 567                                                None
# 569                                                None
# 145                                                None
# 146    a U.S. non- citizen national or a qualified a...
# ...                                                 ...
# 2136                                               None
# 1841                                               None
# 1659                                               None
# 1515                                               None
# 958                                                None
#
#                                                      4   \
# 206                                                None
# 567                                                None
# 569                                                None
# 145                                                None
# 146   IV.Be unable to obtain credit elsewhere at rea...
# ...                                                 ...
# 2136                                               None
# 1841                                               None
# 1659                                               None
# 1515                                               None
# 958                                                None
#
#                                                      5   \
# 206                                                None
# 567                                                None
# 569                                                None
# 145                                                None
# 146   V.Have the legal capacity to incur the obligat...
# ...                                                 ...
# 2136                                               None
# 1841                                               None
# 1659                                               None
# 1515                                               None
# 958                                                None
#
#                                                      6   \
# 206                                                None
# 567                                                None
# 569                                                None
# 145                                                None
# 146   VI. Not have outstanding unpaid judgments obta...
# ...                                                 ...
# 2136                                               None
# 1841                                               None
# 1659                                               None
# 1515                                               None
# 958                                                None
#
#                                            7   \
# 206                                      None
# 567                                      None
# 569                                      None
# 145                                      None
# 146   VII.Not be delinquent on a federal debt
# ...                                       ...
# 2136                                     None
# 1841                                     None
# 1659                                     None
# 1515                                     None
# 958                                      None
#
#                                                      8   \
# 206                                                None
# 567                                                None
# 569                                                None
# 145                                                None
# 146   VIII.Must not have provided FSA with false or ...
# ...                                                 ...
# 2136                                               None
# 1841                                               None
# 1659                                               None
# 1515                                               None
# 958                                                None
#
#                                                      9   ...  \
# 206                                                None  ...
# 567                                                None  ...
# 569                                                None  ...
# 145                                                None  ...
# 146   IX.Not have been convicted under federal or st...  ...
# ...                                                 ...  ...
# 2136                                               None  ...
# 1841                                               None  ...
# 1659                                               None  ...
# 1515                                               None  ...
# 958                                                None  ...
#
#                                                      12  \
# 206                                                None
# 567                                                None
# 569                                                None
# 145                                                None
# 146    or any occasion after April 4, 1996VIII.Be th...
# ...                                                 ...
# 2136                                               None
# 1841                                               None
# 1659                                               None
# 1515                                               None
# 958                                                None
#
#                                                      13  \
# 206                                                None
# 567                                                None
# 569                                                None
# 145                                                None
# 146   XI.Not have provided FSA with false or mislead...
# ...                                                 ...
# 2136                                               None
# 1841                                               None
# 1659                                               None
# 1515                                               None
# 958                                                None
#
#                                                      14    15    16    17  \
# 206                                                None  None  None  None
# 567                                                None  None  None  None
# 569                                                None  None  None  None
# 145                                                None  None  None  None
# 146   XII. Not have been convicted under federal or ...  None  None  None
# ...                                                 ...   ...   ...   ...
# 2136                                               None  None  None  None
# 1841                                               None  None  None  None
# 1659                                               None  None  None  None
# 1515                                               None  None  None  None
# 958                                                None  None  None  None
#
#         18    19    20    21
# 206   None  None  None  None
# 567   None  None  None  None
# 569   None  None  None  None
# 145   None  None  None  None
# 146   None  None  None  None
# ...    ...   ...   ...   ...
# 2136  None  None  None  None
# 1841  None  None  None  None
# 1659  None  None  None  None
# 1515  None  None  None  None
# 958   None  None  None  None
#
# [492 rows x 22 columns]

# %%
# need to find a way to formulate questions from each given question...
